# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-472d27d6-e93d-4beb-a328-9e7ca3e94919" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-472d27d6-e93d-4beb-a328-9e7ca3e94919">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving north_america_2000_2010.csv to north_america_2000_2010.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['north_america_2000_2010.csv']))

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-b72600ae-0fc4-4b9b-b68b-e8ea7c8ca615" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b72600ae-0fc4-4b9b-b68b-e8ea7c8ca615">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving south_america_2000_2010.csv to south_america_2000_2010.csv

# %%
import io
df = pd.read_csv(io.BytesIO(uploaded['south_america_2000_2010.csv']))

# %%
south_america=pd.read_csv('south_america_2000_2010.csv')
north_america=pd.read_csv('north_america_2000_2010.csv')

# %%
north_america
# Out:
#   Country    2000    2001    2002    2003    2004  2005    2006    2007  2008  \
# 0  Canada  1779.0  1771.0  1754.0  1740.0  1760.0  1747  1745.0  1741.0  1735
# 1  Mexico  2311.2  2285.2  2271.2  2276.5  2270.6  2281  2280.6  2261.4  2258
# 2     USA  1836.0  1814.0  1810.0  1800.0  1802.0  1799  1800.0  1798.0  1792
#
#      2009    2010
# 0  1701.0  1703.0
# 1  2250.2  2242.4
# 2  1767.0  1778.0

# %%
south_america
# Out:
#   Country  2000  2001  2002  2003  2004  2005  2006  2007  2008  2009    2010
# 0   Chile  2263  2242  2250  2235  2232  2157  2165  2128  2095  2074  2069.6

# %%
americas= pd.concat ([north_america,south_america])
americas
# Out:
#   Country    2000    2001    2002    2003    2004  2005    2006    2007  2008  \
# 0  Canada  1779.0  1771.0  1754.0  1740.0  1760.0  1747  1745.0  1741.0  1735
# 1  Mexico  2311.2  2285.2  2271.2  2276.5  2270.6  2281  2280.6  2261.4  2258
# 2     USA  1836.0  1814.0  1810.0  1800.0  1802.0  1799  1800.0  1798.0  1792
# 0   Chile  2263.0  2242.0  2250.0  2235.0  2232.0  2157  2165.0  2128.0  2095
#
#      2009    2010
# 0  1701.0  1703.0
# 1  2250.2  2242.4
# 2  1767.0  1778.0
# 0  2074.0  2069.6
